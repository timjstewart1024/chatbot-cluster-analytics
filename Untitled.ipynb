# %%
import utilities

conv = utilities.read_conversations("stjohns.csv")
conv
# Out:
#      short_name    id  conversation               flow_id  \
# 0       stjohns     1             1    F38211883137QDUCKE
# 2       stjohns     3             2    F382118841665YTP21
# 4       stjohns     5             2   F672655459266TA1NPW
# 6       stjohns     7             2    F38211884424Z5YG4I
# 8       stjohns     9             2    F38211884697A3JI4V
# ...         ...   ...           ...                   ...
# 2152    stjohns  2153           978  F1019460556921RUUPZ2
# 2154    stjohns  2155           979  F10194605608205DK5ZM
# 2156    stjohns  2157           980     F1149031442DZIUJC
# 2158    stjohns  2159           981   F147791020235VDM13C
# 2160    stjohns  2161           982   F547805707646SDWCQL
#
#                         timestamp              content  failed author
# 0     2025-01-21T22:25:06.797000Z                GPA ?   False   USER
# 2     2025-01-21T22:28:45.996000Z                gpa ?   False   USER
# ...
